# %%
import socket
target_host = "localhost"
target_port = 8081
client = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
#request = "GET / HTTP/1.1\r\nHost:%s\r\n\r\n" % target_host

data = "stream=1&stdout=1&stdin=1" 

header = ( """
POST /containers/4b7378f43b5f/attach HTTP/1.1
Host: localhost
Connection: keep-alive
Content-Type: application/x-www-form-urlencoded
""" )
content_length = "Content-Length: "+str(len(data))+"\n\n"
#request = "POST /containers/4b7378f43b5f/attach HTTP/1.1"
content_type = "application/x-www-form-urlencoded"

request = header+content_length+data
print(request)

client.connect((target_host,target_port))
client.send(request.encode())
data = b''
# receive some data 
while True:
    response = client.recv(1)
    #http_response = repr(response)
    data+= response
    if data[-4:]== b'\r\n\r\n':
        break
print(response)
# Out:
# POST /containers/4b7378f43b5f/attach HTTP/1.1
# Host: localhost
# Connection: keep-alive
# Content-Type: application/x-www-form-urlencoded
# Content-Length: 25
#
# stream=1&stdout=1&stdin=1
# b'\n'

# %%
"Hellodsd"[-4:]
# Out:
# 'odsd'

# %%
import socket
target_host = "localhost"
target_port = 8081
client = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
#request = "GET / HTTP/1.1\r\nHost:%s\r\n\r\n" % target_host

data = """{
    "Detach": false,
    "Tty": false
}"""

header = ( """
POST /exec/4d080705e3110c3265ed59d151765bd1e0ec8f573de17889b2f4a06cb8675a3d/start HTTP/1.1
Host: localhost
Connection: keep-alive
Content-Type: application/json
""" )
content_length = "Content-Length: "+str(len(data))+"\n\n"
#request = "POST /containers/4b7378f43b5f/attach HTTP/1.1"
#content_type = "application/x-www-form-urlencoded"

request = header+content_length+data
print(request)
exit()

client.connect((target_host,target_port))
client.send(request.encode())

# receive some data 
while True:
    response = client.recv(200)
    print(response.decode())
    client.send("ls".encode())
# Out:
# POST /exec/4d080705e3110c3265ed59d151765bd1e0ec8f573de17889b2f4a06cb8675a3d/start HTTP/1.1
# Host: localhost
# Connection: keep-alive
# Content-Type: application/json
# Content-Length: 41
#
# {
#     "Detach": false,
#     "Tty": false
# }
# HTTP/1.1 101 UPGRADED
# Server: nginx/1.17.10 (Ubuntu)
# Date: Wed, 22 Apr 2020 12:04:14 GMT
# Content-Type: application/vnd.docker.raw-stream
# Connection: upgrade
# Upgrade: tcp
# Api-Version: 1.40
# Docke
# r-Experimental: false
# Ostype: linux
#
# iError: Exec command 4d080705e3110c3265ed59d151765bd1e0ec8f573de17889b2f4a06cb8675a3d is already running
# HTTP/1.1 400 Bad Request
# Server: nginx/1.17.10
#  (Ubuntu)
# Date: Wed, 22 Apr 2020 12:04:14 GMT
# Content-Type: text/html
# Content-Length: 167
# Connection: close
#
# <html>
# <head><title>400 Bad Request</title></head>
# <body>
# <center><h1>400 Bad Requ
# est</h1></center>
# <hr><center>nginx/1.17.10 (Ubuntu)</center>
# </body>
# </html>

# %%
import ctypes
a=202344442
a= a.to_bytes(4,byteorder="big",signed=False)
#print(a)
#a= list(a)
a = [x.to_bytes(1,byteorder="big",signed=False) for x in a]
arr = bytearray()
cmd = b'ls\r\n'
size = (len(cmd)).to_bytes(4,byteorder="big",signed=False)

size = bytearray(size)
size = [x.to_bytes(1,byteorder="big",signed=False) for x in size]
size.insert(0,b'0')
size.insert(0,b'0')
size.insert(0,b'0')
size.insert(0,b'0')
outdata=b''
for x in size:
    outdata+=x
outdata+=cmd
print(outdata)
# Out:
# b'0000\x00\x00\x00\x04ls\r\n'

# %%
import socket
import time

#POST Request Host
target_host = "localhost"

#Post request port
target_port = 8800

#Create TCP Socket Connection
client = socket.socket(socket.AF_INET,socket.SOCK_STREAM)

#request = "GET / HTTP/1.1\r\nHost:%s\r\n\r\n" % target_host

#Parameters for post request of x-www-form-urlenoded
#data = "stream=1&stdout=1&stdin=1" 
data = '{"Detach": false, "Tty": true}'
#data = '{"AttachStdin": true,"AttachStdout": true,"AttachStderr": true,"DetachKeys": "ctrl-p,ctrl-q","Tty": true,"Cmd": ["bash"],"Env": ["FOO=bar","BAZ=quux"]}'

#Request Header
header = ( """POST /exec/d381681ac83df7ad5bb145f89ece6b527b62f809e96e8b41a8e782cdd081f041/start HTTP/1.1
Content-Type: application/json
Host: localhost:8800
Connection: upgrade
Upgrade: tcp
""" )

#Determining content lengtccch from parameter
content_length = "Content-Length: "+str(len(data))+"\n\n"

request = header+content_length+data+'\n\n'
print(request)

client.connect((target_host,target_port))
client.send(request.encode())
data = b''
# receive some data 
while True:
    response = client.recv(50)
    print(response)
    time.sleep(1)
    data+= response
    #Break if last chatacters are \r\n\r\n in byte format
    if data[-4:]== b'\r\n\r\n':
       break
print(response.decode())
#Create ls command in byte format
cmd = b'ls\r\n'

#Convert it to big-endian 4 bytes
size = (len(cmd)).to_bytes(4,byteorder="big",signed=False)

#Create a array so each byte seperates
size = bytearray(size)

#Convert each element for the byte to bigendian as it becomes normal in array
size = [x.to_bytes(1,byteorder="big",signed=False) for x in size]

#insert first byte to specify stdin and padding of 3 bytes
size.insert(0,b'0')
size.insert(0,b'0')
size.insert(0,b'0')
size.insert(0,b'0')
size.append(cmd)

outdata=b''
for x in size:
    outdata+=x
outdata+=cmd
print(outdata)

client.send(b'0')
client.send(b'0')
client.send(b'0')
client.send(b'0')
client.send((len(cmd)).to_bytes(4,byteorder="big",signed=False))
client.send(cmd)
client.send(cmd)
client.send("touch f1.txt\r\n".encode())
while True:
	response = client.recv(1)
	print(response)
	time.sleep(1)
# Out:
# 0

# %%
import requests
import json

exec_url = "http://localhost:8800/containers/183bc47d6823/exec"
headers = {'content-type': 'application/json'}
payload = {

    "AttachStdin": True,
    "AttachStdout": True,
    "AttachStderr": True,
    "DetachKeys": "ctrl-p,ctrl-q",
    "Tty": True,
    "Cmd": 

[

    "bash"

],
"Env": 

    [
        "FOO=bar",
        "BAZ=quux"
    ]

}


response = requests.post(exec_url,headers=headers,data=json.dumps(payload))
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-7033b2c85a96> in <module>
#      29
#      30 response = requests.post(exec_url,headers=headers,data=json.dumps(payload))
# ---> 31 print(response.body)
#
# AttributeError: 'Response' object has no attribute 'body'
